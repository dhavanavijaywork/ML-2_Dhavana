# %% [markdown]
# <a href="https://colab.research.google.com/github/dhavanavijaywork/ML-2_Dhavana/blob/main/ML2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/sample_data/student_data.csv")

# %%
print(df)
# Out:
#    Student_ID  Age  Gender  StudyHours  Attendance  Marks Result
# 0           1   18  Female         2.5        75.0   55.0   Pass
# 1           2   19    Male         4.0        82.0   68.0   Pass
# 2           3   18  Female         NaN        68.0   61.0   Pass
# 3           4   20    Male         6.0        91.0   85.0   Pass
# 4           5   19  Female         5.0        88.0   78.0   Pass
# 5           6   18    Male         1.5        60.0   45.0   Fail
# 6           7   21  Female         7.0         NaN   92.0   Pass
# 7           8   20    Male         4.5        80.0   72.0   Pass
# 8           9   19  Female         3.5        72.0   64.0   Pass
# 9          10   18    Male         2.0        65.0    NaN   Fail

# %%
print(df.head())
# Out:
#    Student_ID  Age  Gender  StudyHours  Attendance  Marks Result
# 0           1   18  Female         2.5        75.0   55.0   Pass
# 1           2   19    Male         4.0        82.0   68.0   Pass
# 2           3   18  Female         NaN        68.0   61.0   Pass
# 3           4   20    Male         6.0        91.0   85.0   Pass
# 4           5   19  Female         5.0        88.0   78.0   Pass

# %%
print(df.tail())
# Out:
#    Student_ID  Age  Gender  StudyHours  Attendance  Marks Result
# 5           6   18    Male         1.5        60.0   45.0   Fail
# 6           7   21  Female         7.0         NaN   92.0   Pass
# 7           8   20    Male         4.5        80.0   72.0   Pass
# 8           9   19  Female         3.5        72.0   64.0   Pass
# 9          10   18    Male         2.0        65.0    NaN   Fail

# %%
df.shape
# Out:
# (10, 7)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'StudyHours', 'Attendance', 'Marks',
#        'Result'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Student_ID      int64
# Age             int64
# Gender         object
# StudyHours    float64
# Attendance    float64
# Marks         float64
# Result         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Age           0
# Gender        0
# StudyHours    1
# Attendance    1
# Marks         1
# Result        0
# dtype: int64

# %%
df = pd.read_csv("/content/sample_data/student_data.csv")

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Age           0
# Gender        0
# StudyHours    1
# Attendance    1
# Marks         1
# Result        1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Age           0
# Gender        0
# StudyHours    0
# Attendance    0
# Marks         0
# Result        0
# dtype: int64

# %%
df.shape
# Out:
# (6, 7)

# %%
df = pd.read_csv("/content/sample_data/student_data.csv")

# %%
print(df)
# Out:
#    Student_ID  Age  Gender  StudyHours  Attendance  Marks Result
# 0           1   18  Female         2.5        75.0   55.0   Pass
# 1           2   19    Male         4.0        82.0   68.0   Pass
# 2           3   18  Female         NaN        68.0   61.0   Pass
# 3           4   20    Male         6.0        91.0   85.0   Pass
# 4           5   19  Female         5.0        88.0   78.0    NaN
# 5           6   18    Male         1.5        60.0   45.0   Fail
# 6           7   21  Female         7.0         NaN   92.0   Pass
# 7           8   20    Male         4.5        80.0   72.0   Pass
# 8           9   19  Female         3.5        72.0   64.0   Pass
# 9          10   18    Male         2.0        65.0    NaN   Fail

# %%
df['StudyHours'] = df['StudyHours'].fillna(df['StudyHours'].mean())

# %%
df['Attendance'] = df['Attendance'].fillna(df['Attendance'].mean())

# %%
df['Marks'] = df['Marks'].fillna(df['Marks'].mean())

# %%
df = df.round(1)

# %%
print(df)
# Out:
#    Student_ID  Age  Gender  StudyHours  Attendance  Marks Result
# 0           1   18  Female         2.5        75.0   55.0   Pass
# 1           2   19    Male         4.0        82.0   68.0   Pass
# 2           3   18  Female         4.0        68.0   61.0   Pass
# 3           4   20    Male         6.0        91.0   85.0   Pass
# 4           5   19  Female         5.0        88.0   78.0    NaN
# 5           6   18    Male         1.5        60.0   45.0   Fail
# 6           7   21  Female         7.0        75.7   92.0   Pass
# 7           8   20    Male         4.5        80.0   72.0   Pass
# 8           9   19  Female         3.5        72.0   64.0   Pass
# 9          10   18    Male         2.0        65.0   68.9   Fail

# %%
df['Result']= df['Marks'].apply(lambda x: 'Pass' if x >= 50 else 'Fail')

# %%
print(df)
# Out:
#    Student_ID  Age  Gender  StudyHours  Attendance  Marks Result
# 0           1   18  Female         2.5        75.0   55.0   Pass
# 1           2   19    Male         4.0        82.0   68.0   Pass
# 2           3   18  Female         4.0        68.0   61.0   Pass
# 3           4   20    Male         6.0        91.0   85.0   Pass
# 4           5   19  Female         5.0        88.0   78.0   Pass
# 5           6   18    Male         1.5        60.0   45.0   Fail
# 6           7   21  Female         7.0        75.7   92.0   Pass
# 7           8   20    Male         4.5        80.0   72.0   Pass
# 8           9   19  Female         3.5        72.0   64.0   Pass
# 9          10   18    Male         2.0        65.0   68.9   Pass

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_909/3657246551.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
print(df)
# Out:
#    Student_ID  Age  Gender  StudyHours  Attendance  Marks Result
# 0           1   18  Female         2.5        75.0   55.0   Pass
# 1           2   19    Male         4.0        82.0   68.0   Pass
# 2           3   18  Female         4.0        68.0   61.0   Pass
# 3           4   20    Male         6.0        91.0   85.0   Pass
# 4           5   19  Female         5.0        88.0   78.0   Pass
# 5           6   18    Male         1.5        60.0   45.0   Fail
# 6           7   21  Female         7.0        75.7   92.0   Pass
# 7           8   20    Male         4.5        80.0   72.0   Pass
# 8           9   19  Female         3.5        72.0   64.0   Pass
# 9          10   18    Male         2.0        65.0   68.9   Pass

# %%
df = pd.read_csv("/content/sample_data/student_data.csv")

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_909/3657246551.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
print(df)
# Out:
#    Student_ID  Age  Gender  StudyHours  Attendance  Marks Result
# 0           1   18    Male         2.5        75.0   55.0   Pass
# 1           2   19    Male         4.0        82.0   68.0   Pass
# 2           3   18  Female         NaN        68.0   61.0   Pass
# 3           4   20    Male         6.0        91.0   85.0   Pass
# 4           5   19  Female         5.0        88.0   78.0    NaN
# 5           6   18    Male         1.5        60.0   45.0   Fail
# 6           7   21  Female         7.0         NaN   92.0   Pass
# 7           8   20    Male         4.5        80.0   72.0   Pass
# 8           9   19  Female         3.5        72.0   64.0   Pass
# 9          10   18    Male         2.0        65.0    NaN   Fail

# %%
df['Marks'] = df['Marks'].fillna(df['Marks'].mean())
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
df['Attendance'] = df['Attendance'].fillna(df['Attendance'].mean())
df['StudyHours'] = df['StudyHours'].fillna(df['StudyHours'].mean())
# Out:
# /tmp/ipykernel_909/1420706016.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
print(df)
# Out:
#    Student_ID  Age  Gender  StudyHours  Attendance      Marks Result
# 0           1   18    Male         2.5   75.000000  55.000000   Pass
# 1           2   19    Male         4.0   82.000000  68.000000   Pass
# 2           3   18  Female         4.0   68.000000  61.000000   Pass
# 3           4   20    Male         6.0   91.000000  85.000000   Pass
# 4           5   19  Female         5.0   88.000000  78.000000    NaN
# 5           6   18    Male         1.5   60.000000  45.000000   Fail
# 6           7   21  Female         7.0   75.666667  92.000000   Pass
# 7           8   20    Male         4.5   80.000000  72.000000   Pass
# 8           9   19  Female         3.5   72.000000  64.000000   Pass
# 9          10   18    Male         2.0   65.000000  68.888889   Fail

# %%
df.describe()
# Out:
#        Student_ID        Age  StudyHours  Attendance      Marks
# count    10.00000  10.000000   10.000000   10.000000  10.000000
# mean      5.50000  19.000000    4.000000   75.666667  68.888889
# std       3.02765   1.054093    1.732051    9.877022  13.892000
# min       1.00000  18.000000    1.500000   60.000000  45.000000
# 25%       3.25000  18.000000    2.750000   69.000000  61.750000
# 50%       5.50000  19.000000    4.000000   75.333333  68.444444
# 75%       7.75000  19.750000    4.875000   81.500000  76.500000
# max      10.00000  21.000000    7.000000   91.000000  92.000000

# %%
plt.hist(df['Marks'])
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.title('Marks Distribution')
# Out:
# Text(0.5, 1.0, 'Marks Distribution')

# %%
plt.scatter(df['StudyHours'], df['Marks'])
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.title('Study Hours vs Marks')
# Out:
# Text(0.5, 1.0, 'Study Hours vs Marks')

# %%
print(df.shape)
print(df.isnull().sum())
print(df.dtypes)
print(df.describe())
# Out:
# (10, 7)
# Student_ID    0
# Age           0
# Gender        0
# StudyHours    0
# Attendance    0
# Marks         0
# Result        1
# dtype: int64
# Student_ID      int64
# Age             int64
# Gender         object
# StudyHours    float64
# Attendance    float64
# Marks         float64
# Result         object
# dtype: object
#        Student_ID        Age  StudyHours  Attendance      Marks
# count    10.00000  10.000000   10.000000   10.000000  10.000000
# mean      5.50000  19.000000    4.000000   75.666667  68.888889
# std       3.02765   1.054093    1.732051    9.877022  13.892000
# min       1.00000  18.000000    1.500000   60.000000  45.000000
# 25%       3.25000  18.000000    2.750000   69.000000  61.750000
# 50%       5.50000  19.000000    4.000000   75.333333  68.444444
# 75%       7.75000  19.750000    4.875000   81.500000  76.500000
# max      10.00000  21.000000    7.000000   91.000000  92.000000
